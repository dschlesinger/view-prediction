# %%
import pandas as pd
import matplotlib.pyplot as plt
import pydicom

# %%
pred = pd.read_csv('../predictions.csv')

# %%
from IPython.display import clear_output

for i, d in pred.iterrows():

    plt.imshow(pydicom.dcmread('../INBreast/ALL-IMGS/' + d['File']).pixel_array)
    plt.show()

    print(d[['Laterality', 'View']])

    if input() == "B":

        break

    clear_output()
# Out:
# Laterality      L
# View          MLO
# Name: 13, dtype: object
